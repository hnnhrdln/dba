# %%
Part 0: The Dataset
The datataset BankMarketingDataSey.csv (csv format with ";" separator) contains data of
marketing campaigns activated by a Portuguese bank. The purpose of the exercise is to predict whether the
customer will subscribe a deposit (variable y). These are the fields of the dataset (extracted from UCI
http://archive.ics.uci.edu/ml/datasets/Bank+Marketing#)
0 - id (numeric)
1 - age (numeric)
2 - job : type of job (categorical: 'admin.', 'blue- collar', 'entrepreneur', 'housemaid',
'management', 'retired', 'self-employed', 'services', 'student', 'technician', 'unemployed',
unknown)
3 - marital : marital status (categorical: 'divorced', 'married', 'single', 'unknown'; note: 'divorced' means divorced or widowed)
means divorced or widowed)
4 - education (categorical: 'basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'illiterate',
'professional.course', 'university.degree', 'unknown')
5 - default: has credit in default? (categorical: 'no','yes','unknown')
6 - housing: has housing loan? (categorical: 'no','yes','unknown')
7 - loan: has personal loan? (categorical: 'no','yes','unknown')
8 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
9 - cons.price.idx: consumer price index - monthly indicator (numeric)
10 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
11 - euribor3m: euribor 3 month rate - daily indicator (numeric)
12 - nr.employed: number of employees - quarterly indicator (numeric)
Part 1: Analysis (10 points)
1. Load the dataset and name it with a variable called "dataset".
2. How many instances are contained in the dataset? _______ The dataset is complete (i.e. for every
instance all attribute values are always specified - there are no "missing values")?
_______ (points 1).
Is the dataset balanced in terms of the class to be predicted? _________
3. Visualize the distribution of ages in a specific plot (points 2)
4. Through analysis of the dataset, is it possible to hypothesize whether the attribute "marital status" affects
in prediction? How does it affect prediction? Justify the answer. (points 3)
________________________________________________________________
5. Calculate a series that represents for each age the percentage of people who have
subscribed to a deposit. Then calculate a series representing for each age the percentage of people who have not
of people who have not made a deposit. To represent graphically the two series
(also in distinct diagrams and to carry out considerations on the obtained result - if they are born)
(points 4).Part 2: Transformation and Prediction (20 points)
1. Scikit-learn uses a numpy array to make its predictions. The elements
of the numpy array must be of the same numeric data type. It is therefore necessary to
transform the dataset to make it usable with scikit.
Transform categorical values into numeric values by assigning a specific value to each category
of values. In particular, assign the value 0 to the "no" value of the "y" attribute and 1 to the value
"yes.
Eliminate any attributes that for some reason (Specify it) are considered unnecessary for the
classification. Eliminate all instances for which there is an attribute that assumes value
unknown. (point 3)
2. You want to predict the subscription of a repository based on the attributes in the dataset.
Divide the dataset so that 3/4 of the elements are contained in a new dataset "train" and
1/4 in the dataset "test" (points 1).
Train the train and evaluate the accuracy obtained with the Decision Tree model calculated on both the
train dataset and on the test dataset. To carry out some considerations on the obtained results, holding
in consideration also the analysis of the confusion matrix. (point 4)
3. Use another prediction model and compare the results obtained. (points 2)
4. Compare the accuracy obtained in steps 2 and 3 with accuracy obtained with a 10 fold
cross validation
Is it more reliable the evaluation made with cross validation or the one made with an arbitrary subdivision
of the dataset in two parts, training set and test set? For what reason? (points 1).
5. Create a new numeric dataset that contains only numeric values of the starting dataset.
starting dataset. Evaluate the accuracy of this dataset using the models proposed in steps 2 and 3.
models proposed in points 2 and 3. (steps 2).
6. Add categorical attributes to the numeric dataset in this way: for each attribute
For each categorical attribute construct a number of boolean attributes equal to the possible values of the category. Each
attribute represents a category The boolean attribute takes the value 1 for the instances of the original dataset that have the value 1.
The boolean attribute takes the value 1 for the instances of the original dataset that have the value of the category that the attribute represents. Evaluate
the accuracy that is obtained with this dataset using the models proposed in steps 2 and 3.
(points 3).
7. Use a regression algorithm to be applied to the dataset in Step 1 to predict "y".
Round off the values obtained to 0 and 1. Compare the results obtained
