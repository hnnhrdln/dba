# %% [markdown]
# Part 0: The Dataset
# The datataset new_weather.csv contains data describing some meteorological indicators of
# Seattle (temperature, atmospheric pressure, dew point, ...). The data are coded
# The data is encoded daily and for each encoding is entered the minimum, maximum and average value of the
# of the indicator. The dataset also has a field ("Event") that shows if on that date there was an atmospheric phenomenon.
# has been an atmospheric phenomenon.
# The aim of the exercise is to predict if on a certain date there has been an atmospheric event
# regardless of its nature.
# Part 1: Analysis (10 points)
# 1. Load the dataset and name it with a variable called "dataset"
# 2. How many instances are contained in the dataset? _______ The dataset is complete (i.e. for every
# (i.e. for each instance all attribute values are always specified - there are no "missing values")?
# _______ If they exist, indicate what they are and whether the absence of these values affects the possibility of
# predict what is required (point 1).
# Is the dataset balanced with respect to the class to be predicted? _________
# 3. Create a new attribute "Range_Temperatures" that measures the daily temperature range.
# Is anything particular observed in the distribution of values? (points 3)
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# _______________________________________________________
# 4. Represent the maximum temperature and minimum temperature in a graph (points 2).
# 5. How many weather events occur in 2015? How are they distributed by types over the months?
# Represent with the most appropriate graph this distribution (points 2).
# 6. Make a pivot table
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.pivot_table.html
# to show for each year, for each month, and for each type of event the average value of the measured
# average value of the measured temperature. Show the result in a diagram (points 2).
# Part 2: Transformation and Prediction (20 points)
# 1. Scikit-learn uses a numpy array to make its predictions. The elements
# of the numpy array must be of the same numeric data type. It is therefore necessary to
# transform the dataset to make it usable with scikit. Create a new dataset
# from the previous one and transform the values of the field "Events" into 1 / 0 depending on whether an event is recorded or not.
# 2. You want to predict whether or not there is an event based on the other attributes in the dataset.
# attributes in the dataset. Split the dataset so that 2/3 of the elements are contained in a new
# dataset "train" and 1/3 in the dataset "test" (point 1).
# Evaluate the accuracy obtained with the BernoulliNB model on both datasets.
# (from sklearn.naive_bayes import BernoulliNB)
# 3. The accuracy value obtained is _____________ (points 1).
# 4. What do you find out by analyzing the confusion matrices? (points 2)
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# _______________________________________________________
# 5. If you use a Decision Tree based model what accuracy value do you get? Does it change
# anything in the confusion matrix? (points 2)
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# _______________________________________________________
# 6. What accuracy value is obtained with a 10 Fold cross validation and the model based on
# Decision Tree ________________ and the model based on BernoulliNB ________________
# Is it more reliable the evaluation made with the cross validation or the one made with an arbitrary subdivision
# of the dataset in two parts, training set and test set? For what reason? (points 2).
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# ______________________________________________________________
# 7. Graphically test and compare some machine learning algorithms chosen from the libraries of
# scikit libraries (point 2).
# 8. Create a new "reduced" dataset with only average values of atmospheric indicators.
# atmospheric indicators. For each feature, divide the range of values into 6 groups. Replace the original
# value of the attribute with a number from 1 to 6 indicating the membership in the specific group.
# group. Evaluate the accuracy obtained with any algorithm used previously
# (punti 3).___________________________________________________________________________________
# ______________________________________
#
# Translated with www.DeepL.com/Translator (free version)
